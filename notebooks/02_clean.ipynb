# %% [markdown]
# ### Run the Full Cleaning Pipeline
# Call `run_pipeline()` from `clean.py` to execute all ETL steps in one shot.

# %%
import sys
# add the parent‑dir’s src folder to the path so the module can be found
sys.path.append('../src')
from clean import run_pipeline   # now the import succeeds
# run_pipeline needs to be pointed at the ../data/raw folder
df_cleaned = run_pipeline(input_path='../data/raw/amazon_sales.csv')
print(df_cleaned.info())
# Out:
# Starting data cleaning pipeline...
# File successfully saved to: data/cleaned/amazon_sales_cleaned.csv
# Pipeline completed successfully!
# <class 'pandas.DataFrame'>
# Index: 128968 entries, 0 to 128974
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   order_id            128968 non-null  str
#  1   date                128968 non-null  datetime64[us]
#  2   status              128968 non-null  str
#  3   fulfilment          128968 non-null  str
#  4   sales_channel       128968 non-null  str
#  5   ship_service_level  128968 non-null  str
#  6   style               128968 non-null  str
#  7   sku                 128968 non-null  str
#  8   category            128968 non-null  str
#  9   size                128968 non-null  str
#  10  asin                128968 non-null  str
#  11  courier_status      128968 non-null  str
#  12  quantity_ordered    128968 non-null  int64
# ...
